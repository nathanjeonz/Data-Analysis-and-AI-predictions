# %%
import numpy as np

# %%
pressure = np.array([100,120,140,150,170,180])
strength = np.array([2000,2050,2060,2200,2400,2450])

# %%
# scatter plot
import matplotlib.pyplot as plt

# %%
plt.scatter(pressure,strength)
x_fit = np.linspace(0.01,20,100)
y = np.exp(x_fit)
plt.plot(y)
